# %%
# !wget -q http://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/notMNIST_small.tar.gz
# !tar -xzf notMNIST_small.tar.gz

# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf 

# 이미지 읽어서 데이터 준비하기
paths = glob.glob('./notMNIST_small/*/*.png')
paths = np.random.permutation(paths)
독립 = np.array([plt.imread(paths[i]) for i in range(len(paths))])
종속 = np.array([paths[i].split('/')[-2] for i in range(len(paths))])
print(독립.shape, 종속.shape)

#데이터 reshape
독립 = 독립.reshape(18724, 28, 28, 1)
종속 = pd.get_dummies(종속)
print(독립.shape, 종속.shape)
# Out:
# (18724, 28, 28) (18724,)
# (18724, 28, 28, 1) (18724, 10)

# %%
# 모델을 완성합니다.
X = tf.keras.layers.Input(shape=[28,28,1])

H = tf.keras.layers.Conv2D(6, kernel_size=5, padding='same', activation='swish')(X)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Conv2D(16, kernel_size=5,activation='swish')(H)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Flatten()(H)
H = tf.keras.layers.Dense(120,activation='swish')(H)
H = tf.keras.layers.Dense(84, activation='swish')(H)
Y = tf.keras.layers.Dense(10,activation='softmax')(H)

model = tf.keras.models.Model(X,Y)
model.compile(loss='categorical_crossentropy', metrics='accuracy')

# %%
model.fit(독립,종속, epochs=10)
# Out:
# Epoch 1/10
# 586/586 [==============================] - 14s 22ms/step - loss: 0.7888 - accuracy: 0.7661
# Epoch 2/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.2888 - accuracy: 0.9152
# Epoch 3/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.2145 - accuracy: 0.9357
# Epoch 4/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.1751 - accuracy: 0.9478
# Epoch 5/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.1526 - accuracy: 0.9513
# Epoch 6/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.1277 - accuracy: 0.9597
# Epoch 7/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.1031 - accuracy: 0.9660
# Epoch 8/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.0868 - accuracy: 0.9722
# Epoch 9/10
# 586/586 [==============================] - 13s 23ms/step - loss: 0.0718 - accuracy: 0.9752
# Epoch 10/10
# 586/586 [==============================] - 13s 22ms/step - loss: 0.0558 - accuracy: 0.9820
